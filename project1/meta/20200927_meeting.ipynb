# %%
# Comp Biomed 
# Notes for call 20200927
# RA, ...

# %% [markdown]
# Note: maybe the repo
# https://gitlab.inf.ethz.ch/COURSE-BIOMED20/team03
#  can be pulled to this environment, but I haven't done so yet (RA)

# %% [markdown]
# # Project 1 description
# [PDF](./project1_description.pdf)
#
# # Overview
#  - decide on and implement a genome indexing strategy
#  - decide on and implement a read alignment method
#  - define and implement routines to read input data and generate correctly formated output
#  - define and apply evaluation metrics to judge the quality of your tool
#
# ## 1: read
# Devise and implement a reader for the input data.
#  - fa: [wiki](https://en.wikipedia.org/wiki/FASTA_format)
#  - fq: [wiki](https://en.wikipedia.org/wiki/FASTQ_format)
#  - sam: [wiki](https://en.wikipedia.org/wiki/SAM_(file_format)), [samtools](https://github.com/samtools/hts-specs/blob/master/SAMv1.pdf)
#
# scalability by amount of samples, length of whole ref, length of p
#
# scalability in space used and time consumed
# **(& performance: Jannik)**
#
# ## 2: write
# We expect you to generate your output alignments in standard [SAM format](https://github.com/samtools/hts-specs/blob/master/SAMv1.pdf).
# The goal of this work package is to understand the output format specification and design and implement
# code that generates correctly formatted output for each of the alignments.
#
# ## 3: index (*)
# Devise and implement a method that generates an index on the input
# data.
# Ideally, this index can be stored on disk and re-used at a later time.
#
#
# BWT+FM
# **(Luca)**
#
# ## 4: alignment (*)
# Develop an alignment software tool that can find the position(s) of one
# or many reads provided in fastq format in a fully indexed genome.
# **(Hendrik)**
#
# ## Quality of alignment
# **(Roman)**
#
# ## Submission
# Code needs to be executable in the provided **conda** environment.
# If additional packages have been approvedfor use by the TA team, please provide a conda recipe.
# Any solution that is not using Python needs to beprovided as a Docker container and
# a detailed README on how to execute the code.
# Please understandthat for practical purposes any code that a qualified TA
# is unable to get running within 10-15 minutesdue to missing information, can not be graded.
#
# # Github
# [GitHub](https://github.com/numpde/Team03)
#
# # Next call
# Sun, Oct 11, 11am
